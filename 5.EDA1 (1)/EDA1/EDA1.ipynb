# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ## 1.Data Cleaning and Preparation:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Cardiotocographic.csv")  #Importing the data

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head() # First 5 Rows display
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail() # Last 5 rows Display
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
df.shape # Information about the row and column counts
# Out:
# (2126, 14)

# %%
#Data Structure
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.dtypes  # Data type of columns
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.info() # Information about the Null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# # Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
# Print the duplicated rows
df[df.duplicated(keep=False)]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1113  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1457  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1113   39.0       0.0  1.0
# 1115   39.0       0.0  1.0
# 1457   35.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df1 = df.drop_duplicates()

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %%
df.columns[df.columns.duplicated()] # to check duplicated columns
# Out:
# Index([], dtype='object')

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#       index          LB        AC        FM        UC        DL   DS   DP  \
# 0         0  120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 1         1  132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0
# 2         2  133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0
# 3         3  134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0
# 4         4  131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0
# ...     ...         ...       ...       ...       ...       ...  ...  ...
# 2119   2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0
# 2120   2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0
# 2121   2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0
# 2122   2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0
# 2123   2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0
#
#       ASTV  MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# # Missing Values and Imputation

# %%
df1.isnull().sum()
# Out:
# index        0
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 167

# %%
import  seaborn as sns
sns.color_palette('Set3')
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883)]

# %%
cols = df1.columns
colours = ['blue','yellow']
sns.heatmap(df1[cols].isnull(),cmap=colours)
# Out:
# <Axes: >

# %%
df1[df1.isnull().any(axis = 1)]
# Out:
#       index  LB        AC        FM        UC        DL  DS  DP       ASTV  \
# 50       50 NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000
# 116     116 NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000
# 126     126 NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000
# 201     201 NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000
# 566     566 NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000
# 574     574 NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000
# 603     603 NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000
# 935     935 NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000
# 936     936 NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000
# 1013   1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000
# 1204   1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000
# ...

# %%
df1.describe()
# Out:
#              index           LB           AC           FM           UC  \
# count  2124.000000  2103.000000  2104.000000  2124.000000  2124.000000
# mean   1062.289077   133.342023     0.003220     0.009904     0.004394
# std     614.095660    11.268266     0.004392     0.067571     0.003340
# min       0.000000    51.842487    -0.019284    -0.480634    -0.014925
# 25%     530.750000   126.000000     0.000000     0.000000     0.001858
# 50%    1061.500000   133.000000     0.001634     0.000000     0.004486
# 75%    1594.250000   140.000000     0.005650     0.002568     0.006536
# max    2125.000000   214.000000     0.038567     0.961268     0.030002
#
#                 DL           DS           DP         ASTV         MSTV  \
# count  2124.000000  2103.000000  2103.000000  2124.000000  2124.000000
# mean      0.001897     0.000003     0.000175    47.012459     1.364345
# std       0.003344     0.000142     0.000840    18.812403     1.174084
# ...

# %%
mean = df1['LB'].mean()
print(mean)
df1.loc[:,'LB'] = df1['LB'].fillna(mean)
# Out:
# 133.3420230800519

# %%
mean = df1['AC'].mean()
print(mean)
df1.loc[:,'AC'] = df1['AC'].fillna(mean)
# Out:
# 0.0032197961979291345

# %%
mean = df1['DS'].mean()
print(mean)
df1.loc[:,'DS'] = df1['DS'].fillna(mean)
# Out:
# 2.511369605097549e-06

# %%
mean = df1['DP'].mean()
print(mean)
df1.loc[:,'DP'] = df1['DP'].fillna(mean)
# Out:
# 0.00017531778446317666

# %%
mean = df1['MLTV'].mean()
print(mean)
df1.loc[:,'MLTV'] = df1['MLTV'].fillna(mean)
# Out:
# 8.28054590298053

# %%
mean = df1['Width'].mean()
print(mean)
df1.loc[:,'Width'] = df1['Width'].fillna(mean)
# Out:
# 70.46105246796047

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     2124 non-null   int64
#  1   LB        2124 non-null   float64
#  2   AC        2124 non-null   float64
#  3   FM        2124 non-null   float64
#  4   UC        2124 non-null   float64
#  5   DL        2124 non-null   float64
#  6   DS        2124 non-null   float64
#  7   DP        2124 non-null   float64
#  8   ASTV      2124 non-null   float64
#  9   MSTV      2124 non-null   float64
#  10  ALTV      2124 non-null   float64
#  11  MLTV      2124 non-null   float64
#  12  Width     2124 non-null   float64
#  13  Tendency  2103 non-null   float64
#  14  NSP       2103 non-null   float64
# dtypes: float64(14), int64(1)
# memory usage: 249.0 KB

# %%
#Mode = df1['NSP'].mode()
#print(Mode)
#df1.loc[:,'NSP'] = df1['NSP'].fillna(Mode)

# %%
df1['Tendency'].unique()
# Out:
# array([ 9.99926014e-01,  0.00000000e+00,  1.00000000e+00, -1.00000000e+00,
#         1.10922946e-02,  3.28970400e-03,             nan,  9.87842382e-01,
#         8.28090200e-03, -2.59343380e-02,  1.00607149e+00, -5.99107200e-03,
#        -1.00661422e+00, -6.47057600e-03,  1.22923532e-02, -1.21476810e-02,
#        -3.78846800e-03,  4.42943800e-03,  1.00312902e+00,  9.81337890e-01,
#         9.85729402e-01,  1.88044200e-03,  1.19756209e-02,  2.38459500e-03,
#        -3.00000000e+00,  2.13996940e-02,  9.71151191e-01, -1.00210848e+00,
#         1.00124823e+00,  6.55067600e-03, -9.94488285e-01,  9.71445618e-01,
#        -4.25352300e-03, -9.97403600e-03, -2.66400120e-02, -1.98864410e-02,
#        -1.89944450e-02, -1.48017800e-03,  8.13726100e-03, -3.07942200e-03,
#        -5.19414200e-03, -9.91883608e-01,  9.84422685e-01,  1.08158800e-02,
#         1.00184071e+00,  1.00308374e+00,  1.00793862e+00,  9.73593786e-01,
# ...

# %%
df1.loc[:, 'NSP'] = df1['NSP'].apply(lambda X: round(float(X)) if pd.notnull(X) else X)

# %%
df1['NSP'].unique()
# Out:
# array([ 2.,  1.,  3., -1., nan,  5.])

# %%
df1.loc[:,'NSP'] = df1['NSP'].replace(-1, 2)
df1.loc[:,'NSP'] = df1['NSP'].replace(5, 3)

# %%
df1['NSP'].unique()
# Out:
# array([ 2.,  1.,  3., nan])

# %%
df1.NSP.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='NSP'>

# %%
df1.NSP.mode()[0]
# Out:
# 1.0

# %%
mode_nsp = df1.NSP.mode()[0]
mode_nsp
# Out:
# 1.0

# %%
df1.loc[:,'NSP'] = df1.NSP.fillna(mode_nsp)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     2124 non-null   int64
#  1   LB        2124 non-null   float64
#  2   AC        2124 non-null   float64
#  3   FM        2124 non-null   float64
#  4   UC        2124 non-null   float64
#  5   DL        2124 non-null   float64
#  6   DS        2124 non-null   float64
#  7   DP        2124 non-null   float64
#  8   ASTV      2124 non-null   float64
#  9   MSTV      2124 non-null   float64
#  10  ALTV      2124 non-null   float64
#  11  MLTV      2124 non-null   float64
#  12  Width     2124 non-null   float64
#  13  Tendency  2103 non-null   float64
#  14  NSP       2124 non-null   float64
# dtypes: float64(14), int64(1)
# memory usage: 249.0 KB

# %%
df1.loc[:, 'Tendency'] = df1['Tendency'].apply(lambda X: round(float(X)) if pd.notnull(X) else X)

# %%
df1['Tendency'].unique()
# Out:
# array([ 1.,  0., -1., nan, -3.,  3.])

# %%
df1.loc[:,'Tendency'] = df1['Tendency'].replace(-1, 1)
df1.loc[:,'Tendency'] = df1['Tendency'].replace(-3, 1)
df1.loc[:,'Tendency'] = df1['Tendency'].replace(3, 0)
#df1.loc['NSP'] = df1['NSP'].replace(-3, 0)
#df1.loc['NSP'] = df1['NSP'].replace(3, 0)

# %%
df1.Tendency.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Tendency'>

# %%
mode_tendency = df1.Tendency.mode()[0]
mode_tendency
# Out:
# 0.0

# %%
df1.loc[:,'Tendency'] = df1.Tendency.fillna(mode_tendency)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     2124 non-null   int64
#  1   LB        2124 non-null   float64
#  2   AC        2124 non-null   float64
#  3   FM        2124 non-null   float64
#  4   UC        2124 non-null   float64
#  5   DL        2124 non-null   float64
#  6   DS        2124 non-null   float64
#  7   DP        2124 non-null   float64
#  8   ASTV      2124 non-null   float64
#  9   MSTV      2124 non-null   float64
#  10  ALTV      2124 non-null   float64
#  11  MLTV      2124 non-null   float64
#  12  Width     2124 non-null   float64
#  13  Tendency  2124 non-null   float64
#  14  NSP       2124 non-null   float64
# dtypes: float64(14), int64(1)
# memory usage: 249.0 KB

# %%
df1[df1.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [index, LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     2124 non-null   int64
#  1   LB        2124 non-null   float64
#  2   AC        2124 non-null   float64
#  3   FM        2124 non-null   float64
#  4   UC        2124 non-null   float64
#  5   DL        2124 non-null   float64
#  6   DS        2124 non-null   float64
#  7   DP        2124 non-null   float64
#  8   ASTV      2124 non-null   float64
#  9   MSTV      2124 non-null   float64
#  10  ALTV      2124 non-null   float64
#  11  MLTV      2124 non-null   float64
#  12  Width     2124 non-null   float64
#  13  Tendency  2124 non-null   float64
#  14  NSP       2124 non-null   float64
# dtypes: float64(14), int64(1)
# memory usage: 249.0 KB

# %%
df1
# Out:
#       index          LB        AC        FM        UC        DL   DS   DP  \
# 0         0  120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 1         1  132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0
# 2         2  133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0
# 3         3  134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0
# 4         4  131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0
# ...     ...         ...       ...       ...       ...       ...  ...  ...
# 2119   2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0
# 2120   2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0
# 2121   2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0
# 2122   2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0
# 2123   2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0
#
#       ASTV  MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
df1.isnull().sum()
# Out:
# index       0
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns
numerical_cols = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width']

# Function to detect and treat outliers using IQR
def treat_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Cap outliers
    df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
    df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    return df

# Visualize outliers before treatment
plt.figure(figsize=(20, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(x=df[col])
    plt.title(f'Before Treatment: {col}')
plt.tight_layout()
plt.show()

#

# %%
#Treat outliers for all numerical columns
for col in numerical_cols:
    df = treat_outliers_iqr(df, col)

# Visualize outliers after treatment
plt.figure(figsize=(20, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(x=df[col])
    plt.title(f'After Treatment: {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.Statistical Summary

# %%
# Verify results
print("Summary Statistics After Outlier Treatment:")
print(df[numerical_cols].describe())
# Out:
# Summary Statistics After Outlier Treatment:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.293227     0.003148     0.001568     0.004362     0.001770
# std       9.979659     0.003850     0.002485     0.003001     0.002668
# min     105.000000    -0.008475    -0.003850    -0.005177    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     161.000000     0.014124     0.006416     0.013564     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2105.0  2105.0  2126.000000  2126.000000  2126.000000  2105.000000
# mean      0.0     0.0    46.981873     1.304644     6.691678     8.022202
# ...

# %% [markdown]
# # 3.Data Visualization:

# %% [markdown]
# ## Histograms Numerical Variables

# %%
numerical_cols = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width']
df1[numerical_cols].hist(bins =20 ,figsize = (20,15))
plt.suptitle('Histograms of Numerical Columns')
plt.show()

# %% [markdown]
# ## Bar Charts Categorical Variables

# %%
categorical_columns = ['Tendency' , 'NSP']
plt.figure(figsize=(12,20))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2,1,i)
    df1[column].value_counts().plot(kind='bar')
    plt.title(column)
plt.suptitle('Bar charts of Categorical Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmaps to explore relationships between pairs of variable

# %%
df_num = df1.select_dtypes('number')
df_num.corr(method=('pearson'))
# Out:
#              index        LB        AC        FM        UC        DL  \
# index     1.000000 -0.113196  0.057046 -0.121786  0.403163  0.254559
# LB       -0.113196  1.000000 -0.063452  0.018809 -0.166642 -0.126557
# AC        0.057046 -0.063452  1.000000  0.009406  0.071552 -0.093330
# FM       -0.121786  0.018809  0.009406  1.000000 -0.053386  0.009641
# UC        0.403163 -0.166642  0.071552 -0.053386  1.000000  0.189737
# DL        0.254559 -0.126557 -0.093330  0.009641  0.189737  1.000000
# DS        0.009814 -0.005439 -0.033109  0.029896 -0.006942  0.058429
# DP        0.126662 -0.047726 -0.083330  0.121248  0.070348  0.144853
# ASTV      0.136220  0.241666 -0.231058 -0.032838 -0.182379 -0.069907
# MSTV      0.113408 -0.169224  0.133903  0.017061  0.189685  0.410216
# ALTV     -0.198605  0.210673 -0.271204 -0.012005 -0.227881 -0.187275
# MLTV     -0.213826 -0.003225 -0.104658 -0.006156 -0.048754 -0.164942
# Width    -0.006857 -0.118375  0.234720  0.097125  0.106550  0.408427
# ...

# %%
sns.heatmap(df_num.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter Plots to Explore relationships between pairs of variables.

# %%
plt.scatter(df['LB'], df['ASTV'])
plt.xlabel('LB')
plt.ylabel('ASTV')
plt.title('Scatter Plot of LB vs ASTV')
plt.show()

# %%
plt.scatter(df['LB'], df['AC'])
plt.xlabel('LB')
plt.ylabel('AC')
plt.title('Scatter Plot of LB vs AC')
plt.show()

# %% [markdown]
# # Pair Plots

# %%
# Select a subset of numerical columns for pairplot
pairplot_cols = ['LB', 'ASTV', 'MSTV', 'Width', 'AC', 'FM']

# Create pairplot
sns.pairplot(df[pairplot_cols])
plt.suptitle('Pairplot of Key Features Colored by NSP', y=1.02)
plt.show()

# %% [markdown]
# ## 4. Pattern Recognition and insights
# ### Identify any correlations between variables and discuss their potential implications.

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Interpretation
# ### 1.Strong Positive Correlation: Values close to 1 indicate a strong positive relationship.
#
# ### 2.Strong Negative Correlation: Values close to -1 indicate a strong negative relationship.
#
# ### 3.Weak or No Correlation: Values close to 0 indicate little to no relationship.
#
# # EX:
#
# ### 1. LB and AC: If there is a positive correlation, it could suggest that higher baseline fetal heart rates are associated with more accelerations, which may indicate fetal well-being.
#
# ### 2. UC and DL: A negative correlation might imply that stronger uterine contractions are associated with fewer late decelerations, which could be a sign of fetal distress.

# %%
# 4.2 Trends and Patterns
# Example: Plotting LB over time (assuming rows are ordered chronologically)
plt.figure(figsize=(10, 6))
plt.plot(df['LB'], color='blue', label='Baseline Fetal Heart Rate (LB)')
plt.title('Trend of Baseline Fetal Heart Rate (LB) Over Time')
plt.xlabel('Time')
plt.ylabel('LB')
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation
# ## Increasing/Decreasing Trends: Indicate whether the variable is generally increasing or decreasing over time.
#
# ## Seasonality: Regular patterns that repeat at fixed intervals.
#
# ## Spikes or Dips: Sudden changes that may indicate significant events or anomalies.
#
# ## Ex:
# ## LB Trend: A gradual increase in baseline fetal heart rate over time could indicate fetal stress or other physiological changes.
#
# ## UC Patterns: Cyclical patterns in uterine contractions might align with expected labor progression.

# %%
## Combining Correlations and Trends
# Example: Scatter plot of LB vs AC with time-based coloring
plt.figure(figsize=(10, 6))
plt.scatter(df['LB'], df['AC'], c=range(len(df)), cmap='viridis')
plt.colorbar(label='Time')
plt.title('Scatter Plot: LB vs AC (Colored by Time)')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Accelerations (AC)')
plt.show()

# %%
## Interpretation
## If the color gradient shows a pattern (e.g., darker points clustering in specific areas), it could indicate that the relationship between LB and AC changes over time.

# %%
## Key Insights and Recommendations
## Insights
## Correlations:

## Strong correlations between certain variables (e.g., LB and AC) may indicate underlying physiological relationships.
## Negative correlations (e.g., UC and DL) could suggest potential stress responses.

## Trends:

## Temporal trends in LB or UC could help identify critical periods during monitoring.
## Cyclical patterns in UC might align with labor stages.
## Recommendations
## Further Analysis:

## Use machine learning models to predict outcomes (e.g., fetal distress) based on correlated variables.

## Investigate causal relationships between variables using advanced statistical methods.

## Actionable Steps:

## Monitor variables with strong correlations more closely during clinical assessments.

## Use trend analysis to identify high-risk periods for intervention.

# %%
# 5. Conclusion
## Key Insights from EDA:
### ✅ Significant correlations
### ✅ Patterns or cycles in the time-series data.
### ✅ Any missing values, outliers, or unexpected trends.

## Impact on Decision-Making:
### 🔹 If two variables are highly correlated, you might remove one to avoid redundancy.
### 🔹 Detecting trends can help in forecasting or predictive modeling.
### 🔹 Identifying outliers may indicate data quality issues or significant events.
